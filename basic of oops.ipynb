# %%
#Bnak account class
class Bankaccount:
    def __init__(self , holder_name ,balance =0):
        self.holder_name =holder_name
        self.balance =balance
    def deposit(self ,amount):
        self.amount +=amount
        print(f"{amount} deposited. new balance {self.balance}")
    def withdraw (self ,amount):
        if amount <=self.balance:
            self.balance-=amount
            print(f"{amount} withdrawn remaining.balance:{self})
        else:
            print("insufficiant balance")
    def check_balance(self):
            return f"account balance for {self.holder_name }: {self.balnce}"

# %%
''' Creating a student class
details 
and marks if less then 40'''
class student:
    def __init__(self ,name , age , marks):
        self.name =name
        self.age =age
        self.marks =marks
    def student_details(self ,name , age):
        print(f"{name} ,{age} ")
    def checking (self , marks):
        if marks >=40:
          print(f"{student} is passed")
        else:
          print(f"{student } is not passed")

# %%
'''Example 5 : Create an employee Managment system
task define an employee class with attribytes like name , id and salery
add mathod to calculate annual salery
add a method to display the employee details'''

class Employee:
    def __init__(self ,name ,id , salery):
        self.name =name
        self.id =id
        self.salery =salery
    def calculate_annual_salery(self):
        return self.salery*12
    def details(self):
        print(f"Employee name :{self.name}")
        print(f"Employee id :{self.id}")
        
Employee1 =Employee("ankit" , 23432 , 2000000)
Employee1.details()
# Out:
# Employee name :ankit
# Employee id :23432

# %% [markdown]
# Exmaple 4: Create a Library system
# Task
# Define a book class with attributes like title ,author ,and , avalability\\
# add a mathods to check avaliablity and borrowreturn the book

# %%
class Book:
    def __init__(self ,title ,author ,avalability):
        self.title =title
        self.author =author
        self.avalability =avalability
    def borrow(self)
