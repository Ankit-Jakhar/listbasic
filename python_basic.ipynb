# %% [markdown]
# # print function`

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(False)
# Out:
# False

# %%
print("india" ,"pakosthan" ,"chin" ,sep ="/")
# Out:
# india/pakosthan/chin

# %%
print("india" ,"bharat" , sep ="-")
# Out:
# india-bharat

# %%
print("Hello" )
print("world")
# Out:
# Hello
# world

# %%
print("Hello" ,end=" ")
print("world")
# Out:
# Hello world

# %% [markdown]
# # Data types

# %%
#integer
print(1e308) #it is the handle 10 the power 308
# Out:
# 1e+308

# %%
print(1e309)
# Out:
# inf

# %%
#string
print('a')
print("a")
print("""a""")
# Out:
# a
# a
# a

# %%
#list or in other language its called array
#used square bracket
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %%
#tuple
#used perenthsis bracket
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %%
#Sets
#used curley bracket
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %%
#Dictionary
#use dkey value pair
print({"Name":"Ankit" ,"age":30 ,"gender":"male"})
# Out:
# {'Name': 'Ankit', 'age': 30, 'gender': 'male'}

# %% [markdown]
# # Comments

# %%
#comment --> ignorable part of code to written to understand the code

# %% [markdown]
# # Variables

# %%
# variables --> variables are fundamental concept that is used in all language
#variables are container that is store data for future use
#no variable declartion

# %%
name ="nithis"
print(name)
# Out:
# nithis

# %%
#Dyanmic typing --> here no need to tell data type of variable , python follows this
#static typing -->here need to tell data type of variable

# %%
name ="ankit"
print(name)
# Out:
# ankit

# %%
name ="4"
print(name)
# Out:
# 4

# %%
name ="false"
print(name)
# Out:
# false

# %%
# Dynamic Binding --> Here one variable can hold multiple data types 
#its viceversa static binding binding the one data types for till end

# %%
#special syntex to declare the variable 
a =5 ; b=6; c =7
print(a,b,c)
# Out:
# 5 6 7

# %%
a,b,c =5,6,7
print(a,b,c)
# Out:
# 5 6 7

# %%
a=b=c =6
print(a ,b,c)
# Out:
# 6 6 6

# %% [markdown]
# # Keywords

# %%
#Pyrhon is a case sensative programming language
#keyword is a reserved word that have a special meaning , 
#keyword can be commands aur perameters
#keyword cant varialble
#

# %%
#python has keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Identifiers

# %% [raw]
# A Python identifier is a name used to identify a variable , function , class , module or other object

# %% [markdown]
# Rules for setting identifier

# %% [markdown]
# (1)can only start with an alphabet or _
# (2) folllowed by 0 or more letter ,_ and digits
# (3)keywors cannot be used for identifiers
