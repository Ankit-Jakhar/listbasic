# %%
# oops --> it is diifrent style of doing coding and used for real world problem solving

# %% [markdown]
# # Class

# %% [markdown]
# '''class --> class is a blueprint of a object . its have two terminology .first is Data or property and second is function or behaviour
# for exampl a class of a car where the wheels of data and milage and spped etc is function of that class
# class is pascalcase (ThePascalCase)
# name of class is pascalcase and data and function is snakecase(color , calculate_avgspeed)
#
# strucutre
#
# class Car:
# color ="blue " #data
# model ="sports" #data
#
#
# def calculate_avg_speed(km , time):
#  #some code'''

# %% [markdown]
# # Object

# %%
''' object is a instance of the class
example --> car(class) --> wegnare(object)


'''
# Out:
# ' object is a instance of the class\nexample --> car(class) --> wegnare(object)\n\n\n'

# %%
#lets makes a class

# function vs methods

'''methods --> methods is special function which is written inside the class and function is not written the class
l.append(1) this is method becoz it is defined in the class
methos ko keval uske andar ka object access akr sakta hain

# %% [markdown]
# # Constructor

# %%
'''Constructor/ magic/ dunder  -->COnstructor is a predefined function or a special function  which  inside code are autometically 
exicute when we create a object , its not call out the object and (__name__     --> is a constructor) and here we write that 
code which is running your aplication in python init is  constructor'''

"""
self -->self is refrence of current instance of of the class . it is use to access variables and methods that belong to the object


"""

# %% [markdown]
# # A ATM System

# %%
class Atm:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()

    def menu(self):
        while True:
            user_input = input('''
Hello, would you like to proceed?
1. Enter 1 to create PIN
2. Enter 2 to deposit
3. Enter 3 to withdraw
4. Enter 4 to check balance
5. Enter 5 to exit
Your choice: ''')

            if user_input == "1":
                self.create_pin()
            elif user_input == "2":
                self.deposit()
            elif user_input == "3":
                self.withdraw()
            elif user_input == "4":
                self.check_balance()
            elif user_input == "5":
                print("Exiting. Thank you!")
                break
            else:
                print("Invalid option. Please try again.")

    def create_pin(self):
        self.pin = input("Enter your new PIN: ")
        print("PIN created successfully!")

    def deposit(self):
        temp = input("Enter your PIN: ")
        if temp == self.pin:
            amount = int(input("Enter amount to deposit: "))
            self.balance += amount
            print("Deposit successful!")
        else:
            print("Invalid PIN.")

    def withdraw(self):
        temp = input("Enter your PIN: ")
        if temp == self.pin:
            amount = int(input("Enter amount to withdraw: "))
            if amount <= self.balance:
                self.balance -= amount
                print("Withdrawal successful!")
            else:
                print("Insufficient balance.")
        else:
            print("Invalid PIN.")

    def check_balance(self):
        temp = input("Enter your PIN: ")
        if temp == self.pin:
            print(f"Your balance is: ₹{self.balance}")
        else:
            print("Invalid PIN.")


# To use the ATM class
atm = Atm()
# Out:
# Hello, would you like to proceed?
# 1. Enter 1 to create PIN
# 2. Enter 2 to deposit
# 3. Enter 3 to withdraw
# 4. Enter 4 to check balance
# 5. Enter 5 to exit
# Your choice:  1
# Enter your new PIN:  3266
# PIN created successfully!
# Hello, would you like to proceed?
# 1. Enter 1 to create PIN
# 2. Enter 2 to deposit
# 3. Enter 3 to withdraw
# 4. Enter 4 to check balance
# 5. Enter 5 to exit
# Your choice:  3
# Enter your PIN:  3266
# Enter amount to withdraw:  1000
# Insufficient balance.
# Hello, would you like to proceed?
# 1. Enter 1 to create PIN
# 2. Enter 2 to deposit
# 3. Enter 3 to withdraw
# 4. Enter 4 to check balance
# 5. Enter 5 to exit
# Your choice:  2
# Enter your PIN:  500000
# Invalid PIN.
# Hello, would you like to proceed?
# 1. Enter 1 to create PIN
# 2. Enter 2 to deposit
# 3. Enter 3 to withdraw
# 4. Enter 4 to check balance
# 5. Enter 5 to exit
# Your choice:  2
# Enter your PIN:  3266
# Enter amount to deposit:  50000
# Deposit successful!
# ...
